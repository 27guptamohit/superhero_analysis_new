# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# I used one of visualizations from the below link:
# https://towardsdatascience.com/introduction-to-data-visualization-in-python-89a54c97fbed

# %%
final_df = pd.read_csv("final_merged_df.csv")

# %%
sns.countplot(final_df['Race'])

# %%
final_df['Eye Color'].value_counts().sort_index().plot.bar()

# %%
final_df['Hair Color'].value_counts().sort_index().plot.bar()

# %%
plt.figure(figsize=(15,8))

sns.heatmap(final_df.corr(), annot=True)

# %%
sns.countplot(final_df['Alive'])

# %%
sns.FacetGrid(final_df, hue="Publisher", size=8) \
   .map(plt.scatter, "Height", "Weight") \
   .add_legend()
# Out:
# /Users/mohitgupta/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
